# %%
#import libraries
from bs4 import BeautifulSoup
import requests
import os

# %%
#identify url we will be scraping
url = "https://www.verywellhealth.com/nexplanon-birth-control-implant-faq-906864#side-effects"

# %%
#access data within url
response = requests.get(url)

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
html = soup.html

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="comp taxlevel-4 vertical-verywellhealth structuredTemplate html mntl-html" data-ab="99,71,99,99,99,99,99,99,86,66,99" data-health-resource-version="4.76.0" data-mantle-resource-version="3.10.95" data-resource-version="4.76.0" id="structuredTemplate_1-0" lang="en">
#  <!--
# <globe-environment environment="prod" application="health" dataCenter="us-east-1"/>
# -->
#  <head class="loc head">
#   <script type="text/javascript">
#   </script>
#   <link href="//adservice.google.com" rel="preconnect"/>
#   <link href="//securepubads.g.doubleclick.net" rel="preconnect"/>
#   <link href="//stats.g.doubleclick.net" rel="preconnect"/>
#   <link href="//js-sec.indexww.com" rel="preconnect"/>
#   <link href="//bcp.crwdcntrl.net" rel="preconnect"/>
#   <link href="//ad.crwdcntrl.net" rel="preconnect"/>
#   <link href="//c.amazon-adsystem.com" rel="preconnect"/>
#   <link href="//cdn.adsafeprotected.com" rel="preconnect"/>
# ...

# %%
bc_type = soup.find('section').find('h1').text
bc_type
# Out:
# 'Nexplanon'

# %%
bc_side_effects = soup.find('div', attrs={'class': 'comp mntl-sc-block mntl-sc-block-html'}).find('ul')
bc_side_effects
