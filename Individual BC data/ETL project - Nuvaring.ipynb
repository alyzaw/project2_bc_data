# %%
#import libraries
from bs4 import BeautifulSoup
import requests
import os

# %%
#identify url we will be scraping
url = "https://www.rxlist.com/nuvaring-drug/patient-images-side-effects.htm#info"

# %%
#access data within url
response = requests.get(url)

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
html = soup.html

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="https://www.w3.org/1999/xhtml">
#  <head>
#   <script class="googleloaded">
# ...

# %%
bc_type = soup.find('section').find('h1').text
bc_type
# Out:
# 'NuvaRing'

# %%
list_symptoms = soup.find('div', attrs = {'class': 'pgContent'}).find_all('ul')
list_symptoms
# Out:
# [<ul>
#  <li><a href="#whatis">What is ethinyl estradiol and etonogestrel (NuvaRing)?</a></li>
#  <li><a href="#sideeffects">What are the possible side effects of this medicine (NuvaRing)?</a></li>
#  <li><a href="#important">What is the most important information I should know about this medicine (NuvaRing)?</a></li>
#  <li><a href="#nottake">What should I discuss with my healthcare provider before using this medicine (NuvaRing)?</a></li>
#  <li><a href="#howtake">How should I use this medicine (NuvaRing)?</a></li>
#  <li><a href="#missdose">What happens if I miss a dose (NuvaRing)?</a></li>
#  <li><a href="#overdose">What happens if I overdose (NuvaRing)?</a></li>
#  <li><a href="#avoid">What should I avoid while using this medicine (NuvaRing)?</a></li>
#  <li><a href="#drugs">What other drugs will affect ethinyl estradiol and etonogestrel (NuvaRing)?</a></li>
#  <li><a href="#moreinfo">Where can I get more information (NuvaRing)?</a></li>
#  </ul>,
# ...
